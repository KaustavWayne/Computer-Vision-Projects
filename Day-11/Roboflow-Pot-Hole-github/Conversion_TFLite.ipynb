# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.52)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8.0->ultralytics) (1.5.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
from ultralytics import YOLO

# Load trained model
model = YOLO("best.pt")

# Export to TensorFlow Lite
model.export(
    format="tflite",
    int8=True,
    imgsz=640
)

print("✅ Model exported successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.52 🚀 Python-3.12.13 torch-2.10.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (6.0 MB)
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=coco8.yaml'
#
# WARNING ⚠️ Dataset 'coco8.yaml' images not found, missing path '/content/datasets/coco8/images/val'
# Downloading https://ultralytics.com/assets/coco8.zip to '/content/datasets/coco8.zip': 100% ━━━━━━━━━━━━ 432.8KB 77.9MB/s 0.0s
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% ━━━━━━━━━━━━ 25/25 1.8Kfiles/s 0.0s
# Dataset download success ✅ (0.4s), saved to /content/datasets
#
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 164.8MB/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 971.0±626.3 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4/4 109.3it/s 0.0s
# val: New cache created: /content/datasets/coco8/labels/val.cache
# WARNING ⚠️ TensorFlow SavedModel: >300 images recommended for INT8 calibration, found 4 images.
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 395ms
# Prepared 4 packages in 1.48s
# Installed 4 packages in 292ms
#  + colorama==0.4.6
#  + onnx==1.21.0
#  + onnxruntime==1.26.0
#  + onnxslim==0.1.93
#
# requirements: AutoUpdate success ✅ 2.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.93...
# ONNX: export success ✅ 4.2s, saved as 'best.onnx' (11.8 MB)
# requirements: Ultralytics requirements ['tf_keras<=2.19.0', 'sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx2tf>=1.26.3,<1.29.0'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 45 packages in 6.49s
# Prepared 8 packages in 12.84s
# Uninstalled 3 packages in 1.36s
# Installed 8 packages in 408ms
#  + ai-edge-litert==2.1.5
#  + backports-strenum==1.3.1
#  + onnx-graphsurgeon==0.6.1
#  + onnx2tf==1.28.8
#  + sng4onnx==2.0.1
#  - tensorboard==2.20.0
#  + tensorboard==2.19.0
#  - tensorflow==2.20.0
#  + tensorflow==2.19.1
#  - tf-keras==2.20.0
#  + tf-keras==2.19.0
#
# requirements: AutoUpdate success ✅ 21.4s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.20.0...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 184.0MB/s 0.0s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 47.9files/s 0.0s
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at 'best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 7, 8400), dtype=tf.float32, name=None)
# Captures:
#   132574584016528: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132574584014992: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   132574584015760: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   132574584019984: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132574584021136: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   132574584016336: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574584020752: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   132574584021328: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574584022480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574584022096: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574584895056: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   132574584894864: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   132574584024016: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   132574584023248: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   132574584021520: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574584023056: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574584025744: TensorSpec(shape=(1, 1, 48, 32), dtype=tf.float32, name=None)
#   132574584024784: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574584021904: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132574584025168: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   132574584023824: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574584026128: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132574584025360: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574584026896: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574584025552: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574584027280: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132574584028240: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574584026320: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132574584024976: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574584027472: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132574584028432: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574584025936: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132574584028816: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574584026512: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574584026704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574584028624: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   132574584029008: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096507152: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132574584027664: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   132574096506960: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574096507536: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   132574096507728: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574096508304: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096508112: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096510224: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574096510416: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096507920: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574096507344: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096509648: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574096510608: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096509264: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574096510992: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096508496: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096508688: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096511376: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   132574096510800: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574096511568: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132574096509840: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   132574096511184: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132574096511952: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   132574096512144: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132574096512720: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096512528: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096514640: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132574096514832: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574096512336: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132574096511760: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574096512912: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096513104: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096515024: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   132574096513680: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132574096514064: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   132574096515408: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574096515600: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   132574096515792: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132574096516176: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   132574096516368: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574096516752: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096515984: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096518096: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574096518288: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096516560: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574096514256: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096517520: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096515216: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096519056: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   132574096518864: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574096517712: TensorSpec(shape=(1, 1, 192, 64), dtype=tf.float32, name=None)
#   132574096517904: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096519632: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096519440: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096521552: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132574096521744: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574096519248: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   132574096517328: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132574096519824: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096520016: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574096522128: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   132574096521936: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096522320: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132574096520976: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574096520592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090003472: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   132574090002896: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574090004432: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574090004048: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574090006160: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090006736: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090004624: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090008656: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090005008: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574090005200: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574090006928: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   132574090007696: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574090007888: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132574090007312: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132574090007120: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574090007504: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   132574090009040: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132574090010384: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574090009232: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574090010576: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132574090010960: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574090013840: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   132574090013648: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   132574090011152: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574090011536: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   132574090012688: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   132574090011920: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   132574090012880: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   132574090005776: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   132574096522704: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090011728: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090004816: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096522512: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090013072: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090006352: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574096522896: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090014224: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090008848: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090002512: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090014608: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132574090010000: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132574090003856: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132574090014992: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090009808: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090003280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090012304: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   132574090008272: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   132574096523088: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090013264: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090008080: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574096521168: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090014416: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090009424: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090003088: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132574090014032: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090008464: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090002704: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132574090016720: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   132574090015184: TensorSpec(shape=(1, 1, 64, 3), dtype=tf.float32, name=None)
#   132574090010768: TensorSpec(shape=(1, 1, 64, 3), dtype=tf.float32, name=None)
#   132574090004240: TensorSpec(shape=(1, 1, 64, 3), dtype=tf.float32, name=None)
#   132574090014800: TensorSpec(shape=(3,), dtype=tf.float32, name=None)
#   132574090009616: TensorSpec(shape=(3,), dtype=tf.float32, name=None)
#   132574090003664: TensorSpec(shape=(3,), dtype=tf.float32, name=None)
#   132574090016528: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132574090016144: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132574090015952: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132574090017872: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   132574090017296: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   132574090017488: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#
#
# TensorFlow SavedModel: export success ✅ 76.9s, saved as 'best_saved_model' (38.9 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.20.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as 'best_saved_model/best_int8.tflite' (3.2 MB)
#
# Export complete (77.6s)
# Results saved to /content/best_saved_model/best_int8.tflite
# Predict:         yolo predict task=detect model=best_saved_model/best_int8.tflite imgsz=640 int8
# Validate:        yolo val task=detect model=best_saved_model/best_int8.tflite imgsz=640 data=/content/Pothole-Detection/data_fixed.yaml int8
# Visualize:       https://netron.app
# ✅ Model exported successfully

# %%
# !zip -r best_saved_model.zip best_saved_model
# Out:
#   adding: best_saved_model/ (stored 0%)
#   adding: best_saved_model/best_integer_quant.tflite (deflated 18%)
#   adding: best_saved_model/best_float16.tflite (deflated 10%)
#   adding: best_saved_model/best_float32.tflite (deflated 14%)
#   adding: best_saved_model/assets/ (stored 0%)
#   adding: best_saved_model/saved_model.pb (deflated 10%)
#   adding: best_saved_model/best_int8.tflite (deflated 21%)
#   adding: best_saved_model/metadata.yaml (deflated 36%)
#   adding: best_saved_model/fingerprint.pb (stored 0%)
#   adding: best_saved_model/variables/ (stored 0%)
#   adding: best_saved_model/variables/variables.data-00000-of-00001 (deflated 86%)
#   adding: best_saved_model/variables/variables.index (deflated 33%)
#   adding: best_saved_model/best_full_integer_quant.tflite (deflated 18%)

# %%
from google.colab import files
files.download("best_saved_model.zip")

# %%
from google.colab import files
files.download("best_saved_model/best_int8.tflite")

# %% [markdown]
# # TFLite Conversion needed for app building
